# %%
import torch

# %%
x = torch.ones(2, 2, requires_grad=True)
print(x)
# Out:
# tensor([[ 1.,  1.],
#         [ 1.,  1.]])

# %%
y = x + 2
print(y)
# Out:
# tensor([[ 3.,  3.],
#         [ 3.,  3.]])

# %%
print(y.grad_fn)
# Out:
# <AddBackward0 object at 0x7f6c8d367208>

# %%
z = y * y * 3
out = z.mean()

print(z, out)
# Out:
# tensor([[ 27.,  27.],
#         [ 27.,  27.]]) tensor(27.)

# %%
a = torch.randn(2, 2)
a = ((a * 3) / (a - 1))
print(a.requires_grad)
a.requires_grad_(True)
print(a.requires_grad)
b = (a * a).sum()
print(b.grad_fn)
# Out:
# False
# True
# <SumBackward0 object at 0x7f6c66b43eb8>

# %%
out.backward()

# %%
print(x.grad)
# Out:
# tensor([[ 4.5000,  4.5000],
#         [ 4.5000,  4.5000]])

# %%
x = torch.randn( 3, requires_grad=True)

y = x * 2
while y.data.norm() < 1000:
    y = y * 2

print(y)
# Out:
# tensor([ -775.1199, -1823.1339,   -30.0540])

# %%
gradients = torch.tensor([0.1, 1.0, 0.0001], dtype=torch.float)
y.backward(gradients)

print(x.grad)
# Out:
# tensor([  204.8000,  2048.0000,     0.2048])

# %%
print(x.requires_grad)
print((x ** 2).requires_grad)

with torch.no_grad():
    print((x ** 2).requires_grad)
# Out:
# True
# True
# False
